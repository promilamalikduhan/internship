# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import statistics as stats

# %%
df=pd.read_csv('World_Happiness.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#df_test=df['Country','Region']
df_grp=df_test.groupby(['Country','Region'],as_index=False).mean()
df_grp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 #df_test=df['Country','Region']
# ----> 2 df_grp=df_test.groupby(['Country','Region'],as_index=False).mean()
#       3 df_grp
#
# NameError: name 'df_test' is not defined

# %%
df.isnull().sum()

# %%
df.corr()

# %%
#creating a correlation matrix between numeric columns
corre=df.corr(method='pearson')
plt.figure(figsize=(10,6))
sns.heatmap(corre,annot=True)


df=y2_df.copy()
df.drop(['Social support’,’life_expectancy’,’Generosity’,’dystopia_residual'],axis=1,inplace=True)

# %%
df_pivot=df_grp.pivot(index='Country',columns=' Happiness Score')

# %%
sns.regplot(x='Happiness Rank', y='Dystopia Residual',data=df)
plt.ylim(0,)

# %%
sns.regplot(x='Happiness Rank', y='Family',data=df)
plt.ylim(0,)

# %%
sns.regplot(x='Happiness Rank', y='Health (Life Expectancy)',data=df)
plt.ylim(0,)

# %%
sns.regplot(x='Economy (GDP per Capita)', y='Trust (Government Corruption)',data=df)
plt.ylim(0,)

# %%
df.info()

# %%
df=df[["Country", "Region", "Happiness Rank", "Happiness Score"]]
df.head(10)

# %% [markdown]
# I run initial summary statistics to have a general idea about the observaions. Also I look Top 10 Happiest country.

# %%
df=df[["Country", "Region", "Happiness Rank", "Happiness Score"]]
df.tail(10)

# %% [markdown]
# I look 10 least Happiest country

# %%
df_1 = pd.DataFrame(np.random.rand(10, 3), columns=['Country', 'Region', 'Happiness Score'])
df_1.plot.box(grid='True') 
plt.title("Happiness Score for Regions and Countries")
#ax = sns.boxplot(x="Country", y="Happiness Score"data=World Happiness)

# %%
ds=pd.DataFrame(data=df)
print(ds)
sns.pairplot(ds)

# %% [markdown]
# discover outliers with mathematical function

# %%
from scipy.stats import zscore

# %%
df.plot(kind='box',subplots=True,layout=(2,6),figsize=(10,10))

# %%
from sklearn.metrics import roc_curve

from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LinearRegression

# %%
plt.plot([0,1],[0,1],'k--')
corre=df.corr(method='spearman')
plt.xlabel('Family')
plt.ylabel('Happiness Score')
plt.title("All Regions: Happiness Score & Family")
plt.show()

# %%
#Happiest Regions

Region()
#Australia & New Zealand
aust_newzealand=[(Region == "Australia and New Zealand") ]

#Subsetting Western Europe
w_europe=[Region == "Western Europe"]

#North America
n_america=[(Region == "North America")]

#Happiest regions Altogether
happy_regions=(aust_newzealand, w_europe, n_america)

#  Unhappiest Region

#Sub-Saharan Africa
sub_saharan_africa=[(Region == "Sub-Saharan Africa")]
# Other Regions

#Latin America & Caribbean
l_america=[(Region == "Latin America and Caribbean")]
#Middle East and Northern Africa
m_east_n_africa=[(Region == "Middle East and Northern Africa")]
#Central and Eastern Europe
central_easteu=[(Region == "Central and Eastern Europe") ]
#Eastern Asia
east_asia =[(Region == "Eastern Asia")]
#Southern Asia
south_asia =[(Region == "Southern Asia")]

# %%
Pearson_coef,p_value=stats.personr[['Generosity'],df('Dystopia Residual')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 Pearson_coef,p_value=stats.personr[['Generosity'],df('Dystopia Residual')]
#
# AttributeError: module 'statistics' has no attribute 'personr'
