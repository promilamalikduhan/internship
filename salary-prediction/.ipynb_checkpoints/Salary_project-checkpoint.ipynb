# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Salary Project.csv')

# %%
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
df.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %%
df.isnull().sum()
# Out:
# rank             0
# discipline       0
# yrs.since.phd    0
# yrs.service      0
# sex              0
# salary           0
# dtype: int64

# %% [markdown]
# There is no Missing values in our Dataset.

# %%
#check for duplicate data

duplicate=df.duplicated()
print(duplicate.sum())
df[duplicate]
# Out:
# 4
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 151  AsstProf          B              4            4  Male   92000
# 163  AsstProf          B              3            3  Male   89942
# 197  AsstProf          B              4            4  Male   92000
# 200  AsstProf          B              4            4  Male   92700

# %% [markdown]
# Since we have 4 duplicate records in the data, we will remove this from the data set so that we get only distinct records. Post removing the duplicate, we will check whether the duplicates have been removed from the data set or not.

# %%
#drop the duplicates
df.drop_duplicates(inplace=True)

# %%
df1=df.duplicated()
df1.sum()
# Out:
# 0

# %% [markdown]
# # Encoding the dataframe

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))
    
    
df
# Out:
#      rank  discipline  yrs.since.phd  yrs.service  sex  salary
# 0     2.0         1.0             19           18  1.0  139750
# 1     2.0         1.0             20           16  1.0  173200
# 2     1.0         1.0              4            3  1.0   79750
# 3     2.0         1.0             45           39  1.0  115000
# 4     2.0         1.0             40           41  1.0  141500
# ..    ...         ...            ...          ...  ...     ...
# 392   2.0         0.0             33           30  1.0  103106
# 393   2.0         0.0             31           19  1.0  150564
# 394   2.0         0.0             42           25  1.0  101738
# 395   2.0         0.0             25           15  1.0   95329
# 396   1.0         0.0              8            4  1.0   81035
#
# [393 rows x 6 columns]

# %% [markdown]
# # Handling Outlier

# %% [markdown]
# Outliers, being the most extreme observations may include the sample max or sample min,or both,depending on whether they are extremely high or low.
#
# We Generally identify outliers with the help of boxplot,so here box plot shows some of the data points outside the range of the data

# %%
df.boxplot(column=['salary'])
plt.show()

# %% [markdown]
# Boxplot before removing outliers

# %% [markdown]
# Above boxplot seems that the variablr 'salary',have outlier present in the variables.these value needs to be trated and there are serval ways of treating them
#
# 1.Drop the outlier value
# 2.Replace the outlier value using the IQR

# %% [markdown]
# # boxplot after removing outlier

# %%
plt.figure(figsize=(22,6))
sns.heatmap(df.corr(),annot=True,linewidth=0.1,linecolor='Black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# it means analyzing 2 variable.since we know there are numerical and catagorical variables,there is a way of analyzing these variable as shown below:
#
#
#     1.Numerical vs. Numerical
#
#       1.scatterplot
#       2.line plot
#       3.heatmap for corelation
#       4.jointplot
#
#     2.catagorical vs. numerical
#
#       1.bar chart
#       2.violin plot
#       3.catagorical box plot
#       4.swarm plot
#
#     3.two catagorical variable
#       1.bar chart
#       2.grouped bar chart
#       3.point plot

# %%
df.corr()
# Out:
#                    rank  discipline  yrs.since.phd  yrs.service       sex  \
# rank           1.000000   -0.080529       0.522381     0.443792  0.135138
# discipline    -0.080529    1.000000      -0.207739    -0.156227  0.000652
# yrs.since.phd  0.522381   -0.207739       1.000000     0.908882  0.155373
# yrs.service    0.443792   -0.156227       0.908882     1.000000  0.158334
# sex            0.135138    0.000652       0.155373     0.158334  1.000000
# salary         0.519823    0.164018       0.414042     0.329624  0.141521
#
#                  salary
# rank           0.519823
# discipline     0.164018
# yrs.since.phd  0.414042
# yrs.service    0.329624
# sex            0.141521
# salary         1.000000

# %%
df.shape
# Out:
# (393, 6)

# %% [markdown]
# Data Visualization
# Correlation
#
#
# 1.Gives quantifiable relationship between features
# 2.Corr is calculated using various methods like 'pearson', 'spearman', etc.
# 3.Corr can be represented using correlation heatmap

# %%
#creating a correlation matrix between numeric columns
corre=df.corr(method='pearson')
plt.figure(figsize=(10,6))
sns.heatmap(corre,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Positive Correlation
#
# Age and Investment Gain
# Age and Investment Loss
# Weekly Hours and Age
# Weekly Hours and Education Years
# Education Years and Investment Gain
# Education Years and Investment Lost
#
# Negative Correlation
#
# Age and Weight
# Weight and Investment Lost
# Weight and Weekly Hours
# Investment Gain and Investment Loss
# Education Years and Company Size

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 393 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           393 non-null    float64
#  1   discipline     393 non-null    float64
#  2   yrs.since.phd  393 non-null    int64
#  3   yrs.service    393 non-null    int64
#  4   sex            393 non-null    float64
#  5   salary         393 non-null    int64
# dtypes: float64(3), int64(3)
# memory usage: 21.5 KB

# %%
df_1 = pd.DataFrame(np.random.rand(10, 3), columns=['rank', 'discipline', 'sex'])
df_1.plot.box(grid='True') 
plt.title("rank")
# Out:
# Text(0.5, 1.0, 'rank')

# %%
df_1 = pd.DataFrame(np.random.rand(10, 3), columns=['yrs.service', 'yrs.since.phd', 'salary'])
df_1.plot.box(grid='True') 
plt.title("salary")
# Out:
# Text(0.5, 1.0, 'salary')

# %%
ds=pd.DataFrame(data=df)
print(ds)
sns.pairplot(ds)
# Out:
#      rank  discipline  yrs.since.phd  yrs.service  sex  salary
# 0     2.0         1.0             19           18  1.0  139750
# 1     2.0         1.0             20           16  1.0  173200
# 2     1.0         1.0              4            3  1.0   79750
# 3     2.0         1.0             45           39  1.0  115000
# 4     2.0         1.0             40           41  1.0  141500
# ..    ...         ...            ...          ...  ...     ...
# 392   2.0         0.0             33           30  1.0  103106
# 393   2.0         0.0             31           19  1.0  150564
# 394   2.0         0.0             42           25  1.0  101738
# 395   2.0         0.0             25           15  1.0   95329
# 396   1.0         0.0              8            4  1.0   81035
#
# [393 rows x 6 columns]

# %%
#scales the data.essentially returns the Z-scores of every attribute

#Z-score also calles a standard score.

from sklearn.preprocessing import StandardScaler
std_scale=StandardScaler()

# %%
df['salary']=std_scale.fit_transform(df[['salary']])
df['yrs.since.phd']=std_scale.fit_transform(df[['yrs.since.phd']])
df['yrs.service']=std_scale.fit_transform(df[['yrs.service']])
#df['rank']=std_scale.fit_transform(df[['rank']])

# %%
df.head(10)
# Out:
#        rank  discipline  yrs.since.phd  yrs.service  sex    salary
# 0  0.640644         1.0      -0.273772     0.018820  1.0  0.851500
# 1  0.640644         1.0      -0.195636    -0.135268  1.0  1.954661
# 2 -0.677540         1.0      -1.445800    -1.136841  1.0 -1.127264
# 3  0.640644         1.0       1.757745     1.636745  1.0  0.035260
# 4  0.640644         1.0       1.367068     1.790834  1.0  0.909214
# 5 -1.995723         1.0      -1.289530    -0.905709  1.0 -0.558369
# 6  0.640644         1.0       0.585716     0.404040  1.0  2.014024
# 7  0.640644         1.0       1.757745     2.099010  1.0  1.115830
# 8  0.640644         1.0      -0.117501     0.172908  1.0  0.175423
# 9  0.640644         1.0      -0.351907     0.018820  0.0  0.496972

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X=df.iloc[: , : -1].values
Y=df.iloc[: , 5].values

# %%
len(X)
# Out:
# 393

# %%
len(Y)
# Out:
# 393

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.5,random_state = 0)

# %%
regressor  = LinearRegression()
regressor.fit(X_train,Y_train)
print('Training Complete')
# Out:
# Training Complete

# %%
# Plotting the regression line
line = regressor.coef_*X+regressor.intercept_

# %%
y_pred = regressor.predict(X_test)

# %%
cmp = pd.DataFrame({'Actual' : Y_test, 'Predicted' : y_pred})
cmp
# Out:
#        Actual  Predicted
# 0   -0.318312   0.315734
# 1   -1.059656  -0.520878
# 2   -0.079772   0.265192
# 3   -0.019453  -0.913304
# 4    1.027874   0.860058
# ..        ...        ...
# 192 -1.316895  -0.800311
# 193 -0.425264   0.478587
# 194 -0.849412  -0.072407
# 195 -1.217957  -0.477426
# 196 -0.492410   0.339198
#
# [197 rows x 2 columns]
