# %%
#Write a python program to scrape first 10 product details which include product name , price , Image URL from
#https://www.bewakoof.com/women-tshirts?ga_q=tshirts .

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
html=urlopen('https://www.bewakoof.com/women-t-shirts')
bs=BeautifulSoup(html,'html.parser')

# %%
productImage=[]
productName=[]
productPrice=[]

productCount=len(bs.find_all('img',class_="productImgTag",partial=False))
if productCount>=10:
    productCount=10
else:
    productCount=productCount
i=0
for i in  range(productCount):
    productimagedetail=bs.find_all('img',class_="productImgTag",partial=False)
    productnamedetail=bs.find_all('div',class_="productCardDetail",partial=False)
    productpricedetail=bs.find_all('span',class_="actualPriceText",partial=False)
    productImage.append(productimagedetail[i]['src'])
    productName.append(productnamedetail[i].text.split(',')[0].split('₹')[0])
    productPrice.append(productpricedetail[i].text)
    i=i+1 
df=pd.DataFrame({'Product Name':productName,'Price':productPrice,'Image URL':productImage})
df
# Out:
#                                         Product Name Price  \
# 0                Women's True Indigo Printed T-Shirt   799
# 1                Sprinkles Half Sleeves AOP T-Shirts   649
# 2  Coral Blush Melange Color Block Raglan Melange...   599
# 3            Grey Melange Color Block Raglan T-Shirt   599
# 4           Ice Water Blue Half Sleeves Tape T-Shirt   849
# 5         Black-Quiet Grey Half Sleeves Tape T-Shirt   849
# 6             Chili Pepper Half Sleeves Tape T-shirt   849
# 7          Extra Fries Half Sleeve T-Shirt Baby Pink   799
# 8      Olive Night-Black-White High Neck Panel Dress  1599
# 9                    Minion Hill Half Sleeve T-shirt   799
#
#                                            Image URL
# 0  https://images.bewakoof.com/t320/women-s-true-...
# 1  https://images.bewakoof.com/t320/sprinkles-hal...
# 2  https://images.bewakoof.com/t320/coral-blush-m...
# 3  https://images.bewakoof.com/t320/grey-melange-...
# ...
