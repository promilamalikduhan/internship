# %%
#Write a python program to scrape product name, price and discounts from https://meesho.com/bagsladies/pl/p7vbp .

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
html=urlopen('https://meesho.com/bagsladies/pl/p7vbp')
bs=BeautifulSoup(html,'html.parser')

# %%
productDiscount=[]
productPrice=[]
productName=[]
productCount=len(bs.find_all('p',{"class":re.compile('Text__StyledText-sc-oo0kvp-0 .*. NewProductCard__DiscountTextParagraph-sc-j0e7tu-16 .*. NewProductCard__DiscountTextParagraph-sc-j0e7tu-16.*')}))
for i in range(productCount):
    productdiscountData=bs.find_all('p',{"class":re.compile('Text__StyledText-sc-oo0kvp-0 .*. NewProductCard__DiscountTextParagraph-sc-j0e7tu-16 .*. NewProductCard__DiscountTextParagraph-sc-j0e7tu-16.*')})
    productDiscount.append(productdiscountData[i].text.split()[0])
    productpriceData=bs.find_all('h5',class_="Text__StyledText-sc-oo0kvp-0")
    productPrice.append(productpriceData[i].text)
    productnameData=bs.find_all('p',{"class":re.compile('Text__StyledText-sc-oo0kvp-0.*.NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4.*.NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4.*')})
    productName.append(productnameData[i].text.split( ',')[0])

# %%
df=pd.DataFrame({'Product Name':productName,'Price':productPrice,'Discount':productDiscount})
df
# Out:
#                             Product Name  Price Discount
# 0        Voguish Alluring Women Handbags   ₹584     ₹100
# 1        Gorgeous Stylish Women Handbags   ₹351     ₹100
# 2     Ravishing Versatile Women Handbags   ₹484     ₹100
# 3       Gorgeous Alluring Women Handbags   ₹323     ₹100
# 4          Elite Alluring Women Handbags   ₹281     ₹100
# 5         Ravishing Fancy Women Handbags   ₹469     ₹100
# 6         Classic Stylish Women Handbags   ₹429     ₹100
# 7           Elite Stylish Women Handbags  ₹1185     ₹100
# 8   Standard Modern Men Bags & Backpacks   ₹705     ₹100
# 9          Voguish Classy Women Handbags   ₹750     ₹100
# 10           Trendy Fancy Women Handbags   ₹199      ₹85
# 11   New Collections Of Garbage Handbags   ₹684     ₹100
# 12      Gorgeous Alluring Women Handbags   ₹384     ₹100
# 13          Elite Stylish Women Handbags   ₹244     ₹100
# 14      Gorgeous Alluring Women Handbags   ₹434     ₹100
# ...
